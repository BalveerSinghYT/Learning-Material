# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
# df = pd.DataFrame({
#     'adani' : 120,
#     'ambani' : 400,
#     'jindal' : 33,
#     'aws' : 4000,
#     'x' : 799,
# }, index = ['brand', 'value'])

df = pd.DataFrame({
    'brand' : ['adani', 'ambani', 'Jindal', 'aws', 'X'],
    'value' : [31, 11, 333, 4.7, 11.3],
})
df
# Out:
#     brand  value
# 0   adani   31.0
# 1  ambani   11.0
# 2  Jindal  333.0
# 3     aws    4.7
# 4       X   11.3

# %%
df.plot(x = 'brand', y = 'value', kind = 'bar')
# Out:
# <Axes: xlabel='brand'>

# %%
df.plot(x = 'brand', y = 'value', kind = 'bar', logy = True)
# Out:
# <Axes: xlabel='brand'>
